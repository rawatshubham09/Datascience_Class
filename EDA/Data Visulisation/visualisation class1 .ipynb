# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(1000,1), pd.date_range("2019-07-01", periods=1000), columns = ["data"])
df
# Out:
#                 data
# 2019-07-01  0.497271
# 2019-07-02  0.857718
# 2019-07-03  0.810249
# 2019-07-04  0.256922
# 2019-07-05  0.960979
# ...              ...
# 2022-03-22  0.391260
# 2022-03-23  0.280681
# 2022-03-24  0.116668
# 2022-03-25  0.405727
# 2022-03-26  0.240852
#
# [1000 rows x 1 columns]

# %%
df.plot();

# %%
df.data.cumsum().plot();

# %%
#cumsum data
df['data1'] = df.data.cumsum()
#sqr of data
df['data2'] = df['data'].apply(lambda x: x**2)
df
# Out:
#                 data       data1     data2
# 2019-07-01  0.497271    0.497271  0.247278
# 2019-07-02  0.857718    1.354989  0.735681
# 2019-07-03  0.810249    2.165238  0.656503
# 2019-07-04  0.256922    2.422160  0.066009
# 2019-07-05  0.960979    3.383139  0.923481
# ...              ...         ...       ...
# 2022-03-22  0.391260  490.729461  0.153085
# 2022-03-23  0.280681  491.010142  0.078782
# 2022-03-24  0.116668  491.126811  0.013612
# 2022-03-25  0.405727  491.532538  0.164615
# 2022-03-26  0.240852  491.773390  0.058010
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize = (12,10));

# %% [markdown]
# # session start:

# %%
df1 = sns.load_dataset('iris')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
gf = df1.plot(figsize = (8,6),title="Iris Data");
gf.set_xlabel("Index")
gf.set_ylabel("Size")
# Out:
# Text(0, 0.5, 'Size')

# %%
df2 = pd.DataFrame(np.random.rand(15,4),columns = [1,2,3,4])
df2
# Out:
#            1         2         3         4
# 0   0.647873  0.100557  0.427331  0.337047
# 1   0.895995  0.427003  0.550868  0.295821
# 2   0.412316  0.803520  0.156766  0.232653
# 3   0.296863  0.058990  0.633457  0.936322
# 4   0.424185  0.723056  0.906422  0.369472
# 5   0.434239  0.708250  0.593946  0.171227
# 6   0.319482  0.615085  0.747457  0.987718
# 7   0.541105  0.632381  0.771610  0.609521
# 8   0.377001  0.733744  0.421170  0.609755
# 9   0.394874  0.960070  0.642246  0.499648
# 10  0.406711  0.523119  0.147871  0.488780
# 11  0.258374  0.112075  0.480162  0.107319
# 12  0.279411  0.524700  0.349935  0.276301
# 13  0.906655  0.799045  0.399369  0.353368
# 14  0.160391  0.892435  0.134949  0.839834

# %%
df2.plot.bar(figsize = (7,5));

# %%
df2.plot.barh();

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.hist(bins=100, figsize = (10,8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df1.hist(figsize = (7,6), color = 'r');

# %%
df1.plot.scatter(x = 'sepal_length', y = 'petal_length');

# %% [markdown]
# so with the inc in sepal length petal lngth also increase

# %%
df1.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'petal_width');

# %%
df1.plot.scatter(x = 'sepal_length', y = 'sepal_width', color = 'r');

# %% [markdown]
# With increase of sepal length the sepal width decreases.

# %%
df1.plot.hexbin(x = 'sepal_length', y = 'sepal_width', gridsize=10);

# %%
d = df1.iloc[:3,:4].T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (18,18), autopct = '%.2f');

# %%
pd.plotting.scatter_matrix(df1, figsize = (12,10));

# %% [markdown]
# ## Plotly and cufflinks

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Python\Python39\python.exe -m pip install --upgrade pip' command.
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %% [markdown]
# first we need to initlise notebook mode and cufflinks offline

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
df1.plot();

# %%
df1.iplot();
# Out:
# <div>                            <div id="1baf1bcc-40b3-4d62-852b-b4756b76f9ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
