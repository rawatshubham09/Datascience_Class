# %% [markdown]
# # Zomoto Dataset EDA

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (11,8)

# %%
df = pd.read_csv('Dataset/zomato.csv', encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_country = pd.read_excel('Dataset/Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_df = pd.merge(df,df_country,on='Country Code',how='left')
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# ## In EDA
#     1. Missing Values
#     2. Explore about Numerical values
#     3. Explore about Categorical Data
#     4. Relation Between Features

# %% [markdown]
# ### Missing values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[feature for feature in df.columns if df[feature].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull(), yticklabels='False', cmap='viridis');

# %%
final_df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
final_df.Country.value_counts().index
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
country_name = final_df.Country.value_counts().index
country_val = final_df.Country.value_counts().values

# %%
# Pi chart top 4 country
plt.figure(figsize=(10,10))
plt.pie(country_val[:4],labels=country_name[:4], autopct='%1.2f%%');

# %% [markdown]
# Observation: Zomato Max Transitaion are from India then followed by USA and UK

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2148
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    27
# 6                2.3          Red        Poor    47
# 7                2.4          Red        Poor    87
# 8                2.5       Orange     Average   110
# 9                2.6       Orange     Average   191
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   315
# 12               2.9       Orange     Average   381
# 13               3.0       Orange     Average   468
# 14               3.1       Orange     Average   519
# 15               3.2       Orange     Average   522
# 16               3.3       Orange     Average   483
# ...

# %%
ratings = final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings.columns
# Out:
# Index(['Aggregate rating', 'Rating color', 'Rating text', 'Rating Count'], dtype='object')

# %% [markdown]
# - Observations:
#     1. 4.5-4.9 ---> Excellent
#     2. 4.0-4.4 ---> VeryGood
#     3. 3.5-3.9 ---> Good
#     4. 2.5-3.4 ---> Average
#     1. 1.8-2.4 ---> Poor
#     1. 0 ---> Not Rated

# %%
sns.barplot(x='Aggregate rating',y='Rating Count', data = ratings);

# %%
sns.barplot(x='Aggregate rating',y='Rating Count', data = ratings, hue='Rating color', palette=['black','red', 'orange', 'yellow','green','green']);

# %% [markdown]
# - Observations:
#     1. Max People dont like to Rate app
#     2. Avg people Rate between 2.5 and 3.9

# %%
# find the country name that has given zero ratings
final_df[final_df['Rating color']=='White'].groupby(['Country']).size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# - Observation:
#     1. Indian Coustmers dont like to rate Product (Lazzy)

# %%
# find out which currency is used by which country

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Country','Currency']).size().reset_index().rename(columns={0:'count'})
# Out:
#            Country                Currency  count
# 0        Australia               Dollar($)     24
# 1           Brazil      Brazilian Real(R$)     60
# 2           Canada               Dollar($)      4
# 3            India      Indian Rupees(Rs.)   8652
# 4        Indonesia  Indonesian Rupiah(IDR)     21
# 5      New Zealand           NewZealand($)     40
# 6      Phillipines        Botswana Pula(P)     22
# 7            Qatar         Qatari Rial(QR)     20
# 8        Singapore               Dollar($)     20
# 9     South Africa                 Rand(R)     60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)     20
# 11          Turkey        Turkish Lira(TL)     34
# 12             UAE      Emirati Diram(AED)     60
# 13  United Kingdom              Pounds(£)     80
# 14   United States               Dollar($)    434

# %%
#Which dountry do have online dilivery
final_df[final_df['Has Online delivery']=='Yes'].groupby(['Country','Has Online delivery']).size().reset_index()
# Out:
#   Country Has Online delivery     0
# 0   India                 Yes  2423
# 1     UAE                 Yes    28

# %%
final_df.groupby(['Country','Has Online delivery']).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %% [markdown]
# - Obsevations : Only India and USA has Online dilivery System

# %%
# City having Maximum order and Percentages using Pie chart

# %%
City_name = final_df.City.value_counts().index
City_val = final_df.City.value_counts().values

# %%
plt.pie(x=City_val[:5],labels=City_name[:5],autopct='%1.2f%%');

# %%
plt.pie(x=City_val,labels=City_name,autopct='%1.2f%%');

# %% [markdown]
# - Observations:
#     1. New Delhi has utilse Zomato Most more then Half of orders are from New Delhi

# %%
# Find top 10 Cusines ordered

foodname = final_df.Cuisines.value_counts().index
food_index = final_df.Cuisines.value_counts().values

plt.pie(x=food_index[:10],labels=foodname[:10],autopct='%1.2f%%');

# %%
pd.DataFrame(final_df.Cuisines.value_counts().reset_index().head(20))
# Out:
#                              index  Cuisines
# 0                     North Indian       936
# 1            North Indian, Chinese       511
# 2                          Chinese       354
# 3                        Fast Food       354
# 4            North Indian, Mughlai       334
# 5                             Cafe       299
# 6                           Bakery       218
# 7   North Indian, Mughlai, Chinese       197
# 8                 Bakery, Desserts       170
# 9                      Street Food       149
# 10                Pizza, Fast Food       131
# 11              Chinese, Fast Food       118
# 12             Mithai, Street Food       116
# 13                    South Indian       112
# 14               Bakery, Fast Food       108
# 15           Chinese, North Indian       105
# 16                         Mughlai       103
# 17             Ice Cream, Desserts        83
# 18                       Ice Cream        74
# 19         North Indian, Fast Food        74

# %%
final_df.size
# Out:
# 210122
